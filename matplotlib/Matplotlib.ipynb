# %% [markdown]
# <a href="https://colab.research.google.com/github/sowmyasameer4/Python/blob/main/matplotlib/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,6])
ypoints=np.array([0,250])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10,5,7])
plt.plot(ypoints)
plt.show()

# %% [markdown]
# ## Matplotlib Markers

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10,5,7])
plt.plot(ypoints,marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10,5,7])
plt.plot(ypoints,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10,5,7])
plt.plot(ypoints,marker='*')
plt.show()

# %% [markdown]
# ## Format Strings fmt

# %% [markdown]
# ### Marker color

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,'o:r')  #marker color "r=red"
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,'o:k')  #k=black
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Marker size (ms)

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='o',ms=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='o',markersize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Marker Edge Color (mec)

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='o',ms=20,mec='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,'o:m',ms=20,mec='g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='o',ms=20,mec='r',mfc='g')
plt.show()

# %% [markdown]
# ## LineStyle (ls)

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='o',ms=15,mec='g',mfc='r',linestyle='dashed') #ls=_ _
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])                                   #shorter syntax
plt.plot(ypoints,marker='o',ms=15,mec='g',mfc='r',ls='--') #lnstyl='dtted' = ls='--'
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])                                             #shorter syntax
plt.plot(ypoints,marker='o',ms=15,mec='k',mfc='w',linestyle='dotted') #lnstyl='dtted' = ls=':'
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='o',ms=15,mec='g',mfc='r',ls=':')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Color-c (line color)

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,color='g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker='o',ms=15,mec='c',c='m',mfc='k')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Line Width

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,linewidth='20.5')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,c='r',linewidth='15')
plt.show()

# %% [markdown]
# ## Multiple Lines

# %%
import matplotlib.pyplot as plt
import numpy as np
y1=np.array([3,8,1,10])
y2=np.array([6,2,7,11])
plt.plot(y1)
plt.plot(y2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=np.array([0,1,2,3])
y1=np.array([3,8,1,10])
x2=np.array([0,1,2,3])
y2=np.array([6,2,7,11])
plt.plot(x1,y1,x2,y2)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=np.array([2,3,1,5])
x2=np.array([1,3,2,6])
plt.plot(x1)
plt.plot(x2)
plt.show()

# %% [markdown]
# ## Labels & Titles

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)
plt.xlabel("Average Pulse")
plt.ylabel("Calory Burnage")
plt.show()

# %% [markdown]
# ### Title for Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
plt.plot(x,y)
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calory Burnage")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

font1={'family':'serif','color':'r','size':20}
font2={'family':'serif','color':'b','size':15}

plt.title("Sports Watch Data",fontdict=font1)
plt.xlabel("Average Pulse",fontdict=font2)
plt.ylabel("Calory Burnage",fontdict=font2)

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

font1={'family':'monospace','color':'r','size':20}
font2={'family':'monospace','color':'b','size':15}

plt.title("Sports Watch Data",fontdict=font1)
plt.xlabel("Average Pulse",fontdict=font2)
plt.ylabel("Calory Burnage",fontdict=font2)

plt.plot(x,y)
plt.show()

# %% [markdown]
# ### POsition Title

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

font1={'family':'monospace','color':'r','size':20}
font2={'family':'monospace','color':'b','size':15}

plt.title("Sports Watch Data",loc='left')
plt.xlabel("Average Pulse")
plt.ylabel("Calory Burnage")

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

font1={'family':'monospace','color':'r','size':20}
font2={'family':'monospace','color':'b','size':15}

plt.title("Sports Watch Data",loc='right')
plt.xlabel("Average Pulse")
plt.ylabel("Calory Burnage")

plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Adding Grid Lines

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

font1={'family':'monospace','color':'r','size':20}
font2={'family':'monospace','color':'b','size':15}

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calory Burnage")

plt.plot(x,y)

plt.grid()

plt.show()

# %% [markdown]
# axis parameter in grid()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

font1={'family':'monospace','color':'r','size':20}
font2={'family':'monospace','color':'b','size':15}

plt.title("Sports Watch Data",loc='left')
plt.xlabel("Average Pulse")
plt.ylabel("Calory Burnage")

plt.plot(x,y)

plt.grid(axis='x')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

font1={'family':'monospace','color':'r','size':20}
font2={'family':'monospace','color':'b','size':15}

plt.title("Sports Watch Data",loc='left')
plt.xlabel("Average Pulse")
plt.ylabel("Calory Burnage")

plt.plot(x,y)

plt.grid(axis='y')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

font1={'family':'monospace','color':'r','size':20}
font2={'family':'monospace','color':'b','size':15}

plt.title("Sports Watch Data",loc='left')
plt.xlabel("Average Pulse")
plt.ylabel("Calory Burnage")

plt.plot(x,y)

plt.grid(axis='both')  #here axis mentioning is not necesssary eg: "plt.grid()"

plt.show()

# %% [markdown]
# ### grid() properties

# %%
x=np.array([80,85,90,95,100,105,110,115,120,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calory Burnage")

plt.plot(x,y)

plt.grid(color='g',ls='--',linewidth=0.5)

plt.show()

# %% [markdown]
# ## Subplots

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)

plt.show()

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,1,2)
plt.plot(x,y)

plt.show()

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,2)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,3)
plt.plot(x,y)


x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,4)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,5)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,6)
plt.plot(x,y)

plt.show()

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)
plt.title("sales")

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,2)
plt.title("income")

plt.plot(x,y)
plt.show()

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)
plt.title("sales")

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,2)
plt.plot(x,y)
plt.title("income")

plt.show()

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("sales")

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("income")

plt.suptitle("My Shop")

plt.show()

# %% [markdown]
# # Scatter

# %%
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([98,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x,y)
plt.show()

# %%
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([98,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x,y,color='hotpink')

x=np.array([2,5,4,1,6,8,3,9,4,11,12,7,6])
y=np.array([101,105,95,85,89,92,95,100,97,94,83,106,103])

plt.scatter(x,y,color='#88c999')

plt.show()

# %%
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([98,86,87,88,111,86,103,87,94,78,77,85,86])

colors=np.array(["yellow","red","maroon","black","green","blue","pink","magenta","gray","brown","orange","violet","cyan"])

plt.scatter(x,y,c=colors)
plt.show()

# %% [markdown]
# ### Colormap

# %%
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([98,86,87,88,111,86,103,87,94,78,77,85,86])

colors=np.array([0,10,20,30,40,45,50,55,60,70,80,90,100])

plt.scatter(x,y,c=colors,cmap='viridis')

plt.colorbar()

plt.show()

# %% [markdown]
# ### Size()

# %%
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([98,86,87,88,111,86,103,87,94,78,77,85,86])

sizes=np.array([10,20,50,100,200,1000,60,90,10,85,1100,600,70])   #size of the dots

plt.scatter(x,y,s=sizes)

plt.show()

# %% [markdown]
# ### Alpha

# %%
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([98,86,87,88,111,86,103,87,94,78,77,85,86])

sizes=np.array([10,20,50,100,200,1000,60,90,10,85,1100,600,70])   #size of the dots

plt.scatter(x,y,s=sizes,alpha=0.5)

plt.show()

# %% [markdown]
# Combine Color Size & Alpha

# %%
x=np.random.randint(100,size=(100))
y=np.random.randint(100,size=(100))

colors=np.random.randint(100,size=(100))

sizes=10*np.random.randint(100,size=(100))

plt.scatter(x,y,c=colors,s=sizes,alpha=0.5,cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# # Bars

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","c","D"])
y=np.array([3,8,1,10])
plt.bar(x,y)
plt.show()

# %%
x=np.array(["APPLES","BANANAS"])
y=np.array([400,350])
plt.bar(x,y)
plt.show()

# %% [markdown]
# ## Horizontal Bars - Barh()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","c","D"])
y=np.array([3,8,1,10])
plt.barh(x,y)
plt.show()

# %%
x=np.array(["APPLES","BANANAS"])
y=np.array([200,350])
plt.barh(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","c","D"])
y=np.array([3,8,1,10])
plt.bar(x,y,color='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","c","D"])
y=np.array([3,8,1,10])
plt.barh(x,y,color='r')
plt.show()

# %% [markdown]
# ### Bar Width

# %%
x=np.array(["A","B","C","D","E","F"])
y=np.array([1985,3000,1005,2012,4001,1950])
plt.bar(x,y,width=0.2)
plt.show()

# %%
x=np.array(["A","B","C","D","E","F"])
y=np.array([1985,3000,1005,2012,4001,1950])
plt.bar(x,y,width=0.1,color='k')
plt.show()

# %% [markdown]
# ### Bar Height

# %%
x=np.array(["A","B","C","D","E","F"])
y=np.array([1985,3000,1005,2012,4001,1950])
plt.barh(x,y,height=0.9)
plt.show()

# %%
x=np.array(["A","B","C","D","E","F"])
y=np.array([1985,3000,1005,2012,4001,1950])
plt.barh(x,y,height=0.4,color='c')
plt.show()

# %% [markdown]
# # Histogram

# %%
import numpy as np
x=np.random.normal(170,10,250)
print(x)
# Out:
# [166.2312859  176.48105389 168.22414961 171.56236795 178.94962197
#  164.13114526 180.27682444 173.77064208 161.99465235 185.05423809
#  175.8903493  175.21388405 175.53418165 172.83018394 168.92670876
#  187.6631111  176.30274958 160.05374429 184.5855311  181.15697996
#  157.42562823 161.77805247 162.07566849 160.73737955 168.03233645
#  184.81090361 181.21606217 165.56386194 174.22785359 154.07573009
#  173.50665755 152.7066731  163.33955176 161.2865837  170.57759759
#  170.12098325 150.97650762 167.90171438 166.26339332 182.16024497
#  172.17389846 179.37822602 169.43968356 160.34019926 177.46986502
#  161.19154355 180.04877176 178.64481269 161.18225583 183.25732808
#  158.65640195 166.37276013 180.54236027 172.0481953  165.79925029
#  160.10643282 158.81577081 169.163945   165.57353197 184.47228659
#  163.46551715 186.28647144 170.19316105 184.62681489 166.03733233
#  163.83054058 166.93450683 162.14153836 175.45592365 154.5141882
# ...

# %%
x=np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
y=np.array([35,25,25,15])
plt.pie(y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Labels

# %%
y=np.array([35,25,25,15])
mylabels=(["APPLE","BANANA","CHERRY","MANGO"])
plt.pie(y,labels=mylabels)
plt.show()

# %%
x=np.array([35,25,25,15])
mylabels=(["APPLE","BANANA","CHERRY","MANGO"])
plt.pie(y,labels=mylabels)
plt.show()

# %% [markdown]
# ##  Start Angle-startangle()

# %%
x=np.array([35,25,25,15])
mylabels=(["APPLE","BANANA","CHERRY","MANGO"])
plt.pie(y,labels=mylabels,startangle=90)   #starting angle (otherwise it starts from x-axix)
plt.show()

# %%
x=np.array([35,25,25,15])
mylabels=(["APPLE","BANANA","CHERRY","MANGO"])
plt.pie(y,labels=mylabels,startangle=160)
plt.show()

# %% [markdown]
# ## Explode

# %%
y=np.array([35,10,25,30])
mylabels=["APPLE","ORANGE","MANGO","PAPAYA"]
myexplode=[0.2,0,0,0]
plt.pie(y,labels=mylabel,explode=myexplode)
plt.show()

# %%
y=np.array([35,10,25,30])
mylabels=["APPLE","ORANGE","MANGO","PAPAYA"]
myexplode=[0,0,0,0.4]
plt.pie(y,labels=mylabel,explode=myexplode)
plt.show()

# %% [markdown]
# ## Shadow

# %%
y=np.array([35,10,25,30])
mylabels=["APPLE","ORANGE","MANGO","PAPAYA"]
myexplode=[0.2,0,0,0]
plt.pie(y,labels=mylabel,explode=myexplode,shadow=True)
plt.show()

# %%
y=np.array([35,10,25,30])
mylabels=["APPLE","ORANGE","MANGO","PAPAYA"]
mycolors=["red","ORANGE","yellow","hotpink"]
plt.pie(y,labels=mylabel,colors=mycolors)
plt.show()

# %%
y=np.array([35,10,25,30])
mylabels=["APPLE","ORANGE","MANGO","PAPAYA"]
mycolors=["red","ORANGE","yellow","hotpink"]
myexplode=[0,0,0,0.2]
plt.pie(y,labels=mylabel,colors=mycolors,explode=myexplode,shadow=True)
plt.show()

# %% [markdown]
# ## Legend

# %%
y=np.array([35,25,25,15])
mylabels=["APPLES","BANANAS","CHERRRIES","DATES"]
plt.pie(y,labels=mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ## Legends with Header

# %%
y=np.array([35,25,25,15])
mylabels=["APPLES","BANANAS","CHERRRIES","DATES"]
plt.pie(y,labels=mylabels)
plt.legend(title="Four Fruits")
plt.show()

# %% [markdown]
# # Waffle Chart

# %%
# !pip install pywaffle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.6/25.6 MB 85.4 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from pywaffle import Waffle

fig=plt.figure(FigureClass=Waffle,
               rows=5,
               columns=10,
               values=[48,46,6],
               figsize=(5,3))
plt.show()
# Out:
# <Waffle size 500x300 with 1 Axes>

# %%
fig=plt.figure(FigureClass=Waffle,
               rows=5,
               columns=10,
               values=[10,52,38],
               figsize=(8,5))
plt.show()
# Out:
# <Waffle size 800x500 with 1 Axes>

# %%
data={'Democratic':48,'Republic':46,'libertarian':3}
fig=plt.figure(FigureClass=Waffle,
               rows=5,
               values=data,
               legend={'loc':'upper left','bbox_to_anchor':(1.1,1)})
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
data={'Democratic':48,'Republic':46,'libertarian':3}
fig=plt.figure(
    FigureClass=Waffle,
               rows=5,
               values=data,
               colors=["red","green","yellow"],
               title={'label':'Vote percentage in 2016 US presidential Election','loc':'left'},
               labels=[f"{k}({v}%)"for k,v in data.items()],
               legend={'loc':'lower left','bbox_to_anchor':(0,-0.4),'ncol':len(data),'framealpha':0},
               starting_location='NW',
               block_arranging_style='snake'
)
fig.set_facecolor('#EEEEEE')
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
data={'Democratic':48,'Republic':46,'libertarian':3}
fig=plt.figure(
    FigureClass=Waffle,
               rows=5,
               values=data,
               colors=["red","green","black"],
               legend={'loc':'upper left','bbox_to_anchor':(1,1)},
              icons='child',
              font_size=12,
               icon_legend=True)
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %% [markdown]
# # Word Cloud

# %%
# !pip install wordcloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
text="name  is sowmya sowmya sowmya sowmya sowmya and"
wordcloud=WordCloud(width=480,height=480,margin=0).generate(text)
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis("off")
plt.margins(x=0,y=0)
plt.show()
